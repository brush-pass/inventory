# %%
from ipywidgets import FileUpload
from IPython.display import display
upload = FileUpload(accept='.txt', multiple=True)
display(upload)
# Out:
# FileUpload(value={}, accept='.txt', description='Upload', multiple=True)

# %%
for name, file_info in upload.value.items():
    print(name)
# Out:
# shelf-errors-br-feb-15.txt

# %%
pip install jupyter_dashboards
# Out:
# ...
#      |████████████████████████████████| 2.9 MB 20.7 MB/s
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for jupyter-dashboards: filename=jupyter_dashboards-0.7.0-py3-none-any.whl size=3643504 sha256=bd741381fb68d2f4a73b26d9df3119ede6812124e07677f9393730a5b9cba4c9
#   Stored in directory: /home/jovyan/.cache/pip/wheels/8d/eb/57/e0bb090e421c14f9bea05f95f97f3cb036ab3058e27ad97170
# Successfully built jupyter-dashboards
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !jupyter dashboards quick-setup --sys-prefix
# Out:
# Installing /opt/conda/lib/python3.9/site-packages/jupyter_dashboards/nbextension -> jupyter_dashboards
# Making directory: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/
# Making directory: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook
# Copying: /opt/conda/lib/python3.9/site-packages/jupyter_dashboards/nbextension/notebook/link-css.js -> /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/link-css.js
# Copying: /opt/conda/lib/python3.9/site-packages/jupyter_dashboards/nbextension/notebook/main.js -> /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/main.js
# Making directory: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components
# Making directory: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text
# ...

# %%
# !jupyter nbextension enable jupyter_dashboards --py --sys-prefix
# Out:
# Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-nbextension", line 10, in <module>
#     sys.exit(main())
#   File "/opt/conda/lib/python3.9/site-packages/jupyter_core/application.py", line 269, in launch_instance
#     return super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.9/site-packages/notebook/nbextensions.py", line 980, in start
#     super().start()
#   File "/opt/conda/lib/python3.9/site-packages/jupyter_core/application.py", line 258, in start
#     self.subapp.start()
#   File "/opt/conda/lib/python3.9/site-packages/notebook/nbextensions.py", line 888, in start
#     self.toggle_nbextension_python(self.extra_args[0])
#   File "/opt/conda/lib/python3.9/site-packages/notebook/nbextensions.py", line 861, in toggle_nbextension_python
#     return toggle(module,
# ...

# %%
# !pip3 list
# Out:
# Package                       Version
# ----------------------------- -----------
# alabaster                     0.7.12
# alembic                       1.7.5
# altair                        4.2.0
# anyio                         3.4.0
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# async-generator               1.10
# attrs                         21.4.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# bash_kernel                   0.7.2
# beautifulsoup4                4.11.1
# bleach                        4.1.0
# blinker                       1.4
# bokeh                         2.4.3
# boltons                       21.0.0
# Brian2                        2.5.1
# Brotli                        1.0.9
# brotlipy                      0.7.0
# cached-property               1.5.2
# Cartopy                       0.20.2
# certifi                       2022.9.24
# ...

# %%
# !jupyter nbextension list
# Out:
# Known nbextensions:
#   config dir: /opt/conda/etc/jupyter/nbconfig
#     notebook section
#       jupyter-matplotlib/extension  enabled
#       - Validating: OK
#       jupyterlab-plotly/extension  enabled
#       - Validating: OK
#       nbdime/index  enabled
#       - Validating: OK
#       voila/extension  enabled
#       - Validating: OK
#       webio-jupyter-nbextension/nbextension  enabled
#       - Validating: OK
#       jupyter-js-widgets/extension  enabled
#       - Validating: OK
#     tree section
#       ipyparallel/main  enabled
#       - Validating: OK

# %%
# !pip3 install  jupyter_dashboards
# Out:
# ...
#      |████████████████████████████████| 2.9 MB 21.0 MB/s
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for jupyter-dashboards: filename=jupyter_dashboards-0.7.0-py3-none-any.whl size=3643504 sha256=d0bd9e8154ad9c369d21e8129844fe52347d40ca2e5c8ab0d941063cf84c54c3
#   Stored in directory: /home/jovyan/.cache/pip/wheels/8d/eb/57/e0bb090e421c14f9bea05f95f97f3cb036ab3058e27ad97170
# Successfully built jupyter-dashboards
# ...

# %%
# !pip install --upgrade jupyter_dashboards

# %%
# !jupyter dashboards quick-setup --sys-prefix
# Out:
# Installing /opt/conda/lib/python3.9/site-packages/jupyter_dashboards/nbextension -> jupyter_dashboards
# Making directory: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/
# Making directory: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook
# Copying: /opt/conda/lib/python3.9/site-packages/jupyter_dashboards/nbextension/notebook/link-css.js -> /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/link-css.js
# Copying: /opt/conda/lib/python3.9/site-packages/jupyter_dashboards/nbextension/notebook/main.js -> /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/main.js
# Making directory: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components
# Making directory: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text
# ...

# %%
# !jupyter nbextension install --py jupyter_dashboards --sys-prefix
# Out:
# Installing /opt/conda/lib/python3.9/site-packages/jupyter_dashboards/nbextension -> jupyter_dashboards
# Up to date: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/link-css.js
# Up to date: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/main.js
# Up to date: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text/LICENSE
# Up to date: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text/text.js
# Up to date: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text/package.json
# Up to date: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text/bower.json
# Up to date: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text/.bower.json
# ...

# %%
# !jupyter nbextension enable jupyter_dashboards --py --sys-prefix
# Out:
# Enabling notebook extension jupyter_dashboards/notebook/main...
#       - Validating: OK

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -----------
# alabaster                     0.7.12
# alembic                       1.7.5
# altair                        4.2.0
# anyio                         3.4.0
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# async-generator               1.10
# attrs                         21.4.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# bash_kernel                   0.7.2
# beautifulsoup4                4.11.1
# bleach                        4.1.0
# blinker                       1.4
# bokeh                         2.4.3
# boltons                       21.0.0
# Brian2                        2.5.1
# Brotli                        1.0.9
# brotlipy                      0.7.0
# cached-property               1.5.2
# Cartopy                       0.20.2
# certifi                       2022.9.24
# ...

# %%
# !pip install --upgrade jupyter_dashboards

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -----------
# alabaster                     0.7.12
# alembic                       1.7.5
# altair                        4.2.0
# anyio                         3.4.0
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# async-generator               1.10
# attrs                         21.4.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# bash_kernel                   0.7.2
# beautifulsoup4                4.11.1
# bleach                        4.1.0
# blinker                       1.4
# bokeh                         2.4.3
# boltons                       21.0.0
# Brian2                        2.5.1
# Brotli                        1.0.9
# brotlipy                      0.7.0
# cached-property               1.5.2
# Cartopy                       0.20.2
# certifi                       2022.9.24
# ...

# %%
# !jupyter nbextension install --py jupyter_dashboards --sys-prefix
# Out:
# Installing /opt/conda/lib/python3.9/site-packages/jupyter_dashboards/nbextension -> jupyter_dashboards
# Up to date: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/link-css.js
# Up to date: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/main.js
# Up to date: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text/LICENSE
# Up to date: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text/text.js
# Up to date: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text/package.json
# Up to date: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text/bower.json
# Up to date: /opt/conda/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text/.bower.json
# ...

# %%
# !jupyter nbextension enable jupyter_dashboards --py --sys-prefix
# Out:
# Enabling notebook extension jupyter_dashboards/notebook/main...
#       - Validating: OK

# %%
# !jupyter nbextension list
# Out:
# Known nbextensions:
#   config dir: /opt/conda/etc/jupyter/nbconfig
#     notebook section
#       jupyter-matplotlib/extension  enabled
#       - Validating: OK
#       jupyterlab-plotly/extension  enabled
#       - Validating: OK
#       nbdime/index  enabled
#       - Validating: OK
#       voila/extension  enabled
#       - Validating: OK
#       webio-jupyter-nbextension/nbextension  enabled
#       - Validating: OK
#       jupyter-js-widgets/extension  enabled
#       - Validating: OK
#       jupyter_dashboards/notebook/main  enabled
#       - Validating: OK
#     tree section
#       ipyparallel/main  enabled
#       - Validating: OK

# %%
# !jupyter nbextension enable
# Out:
# Please specify an nbextension/package to enable or disable

# %%
# !jupyter nbextension enable jupyter_dashboards
# Out:
# Enabling notebook extension jupyter_dashboards...
#       - Validating: problems found:
#         - require?  X jupyter_dashboards

# %%
# !jupyter nbextension enable jupyter_dashboards --py --sys-prefix
# Out:
# Enabling notebook extension jupyter_dashboards/notebook/main...
#       - Validating: OK

# %%
# !jupyter nbextension install jupyter_dashboards
# Out:
# Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-nbextension", line 10, in <module>
#     sys.exit(main())
#   File "/opt/conda/lib/python3.9/site-packages/jupyter_core/application.py", line 269, in launch_instance
#     return super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.9/site-packages/notebook/nbextensions.py", line 980, in start
#     super().start()
#   File "/opt/conda/lib/python3.9/site-packages/jupyter_core/application.py", line 258, in start
#     self.subapp.start()
#   File "/opt/conda/lib/python3.9/site-packages/notebook/nbextensions.py", line 708, in start
#     self.install_extensions()
#   File "/opt/conda/lib/python3.9/site-packages/notebook/nbextensions.py", line 679, in install_extensions
#     full_dests = install(self.extra_args[0],
# ...

# %%
# !conda install jupyter_dashboards -c conda-forge
